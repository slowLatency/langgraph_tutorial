# %%
from typing import Literal, TypedDict
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os

load_dotenv()

class AgentState(TypedDict):
    messages: list
    
llm = ChatOpenAI(api_key=os.getenv("OPENAI_API_KEY"), model="gpt-5-mini", temperature=0)

def chat(state):
    response = llm.invoke(state["messages"])
    print(f"AI: {response.content}")
    return state

chat_agent = StateGraph(AgentState)
chat_agent.add_node("chat", chat)
chat_agent.add_edge(START, "chat")
chat_agent.add_edge("chat",END)

chat_agent_compiled = chat_agent.compile()

user_input = input("Enter: ")
while user_input.lower() != "exit":
    chat_agent_compiled.invoke(
        {
            "messages": [HumanMessage(content=user_input)]
        }
    )
    user_input = input("Enter: ")
# Out:
# AI: Hi — how can I help you today?
#
# You can ask a question, request writing or editing, get coding help, ask for summaries/translations, plan something, or just chat.
# AI: I'm an AI, so I don't have feelings, but I'm up and running and ready to help. What can I do for you today?
# AI: Nice to meet you, Adib. How can I help you today?
# AI: I don’t know — I don’t have access to personal data about you unless you tell me. What would you like me to call you? (You can give a full name, first name, nickname, and/or pronouns.)
# AI: Hi — how can I help you today?
#
# If you’re not sure how to start, here are examples of things I can do (pick one or describe your own):
#
# - Write or edit text: "Draft a 300-word LinkedIn post about remote onboarding for managers in a professional tone."
# - Answer a question or explain a concept: "Explain CRISPR in simple terms with an example."
# - Help with code: "Fix this Python function that sorts a list — here’s the code: [paste]."
# - Summarize or analyze: "Summarize this article and list the three main takeaways: [paste text or link]."
# - Translate or rewrite: "Translate this paragraph into Spanish and keep it formal."
# - Brainstorm: "Give me 10 name ideas for a productivity app for students."
# - Plan or outline: "Create a one-week study plan to learn basic statistics with resources."
# - Troubleshoot: "My Mac won’t connect to Wi‑Fi — what steps should I try?"
#
# When you reply, it helps if you include:
# - The task and desired output (format, length, tone).
# - Any necessary context or source text.
# - Constraints or preferences (deadline, audience, code language).
#
# What would you like to do first?
